# %% [markdown]
# # What kind of data do we have? How can we resolve the missing data?
# Our aim is to analyze how we handle missing values affects our descriptive statistics and visualizations of a data set.
# We have data from http://archive.ics.uci.edu/ml/datasets/Wholesale+customers
# "The data set refers to clients of a wholesale distributor. It includes the annual spending in monetary units (m.u.) on diverse product categories"
# ## Descriptive Statistics to Compare our results to:
# (Minimum, Maximum, Mean, Std. Deviation)
# FRESH (	3, 112151, 12000.30, 12647.329)
# MILK	(55, 73498, 5796.27, 7380.377)
# GROCERY	(3, 92780, 7951.28, 9503.163)
# FROZEN	(25, 60869, 3071.93, 4854.673)
# DETERGENTS_PAPER (3, 40827, 2881.49, 4767.854)
# DELICATESSEN (3, 47943, 1524.87, 2820.106)
#
# REGION	Frequency
# Lisbon	77
# Oporto	47
# Other Region	316
# Total	440
#
# CHANNEL	Frequency
# Horeca	298
# Retail	142
# Total	440
#
# ## How to Handle Missing Values?
# I am picking for my first approach to ignore the tuples with missing values and for my second approach to fill in the missing values with the most probable value. I think it would be interesting to compare the descriptive statistics and visualizations from the complete data set to those of a data set where we omit the tuples with the missing values from our calculations and to those of a data set where we replace the missing values.

# %%
#first, we get information from the complete data set and convert to df
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#matplotlib.style.use('ggplot')
i = 0
dfWhole = pd.DataFrame(columns=['Channel','Region', 'Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_paper', 'Delicassen'])
with open('WholesaleCustomersData.csv', 'rt') as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        if ('Channel' not in row): #if the row doesn't contain an empty value and is not the first row
            #convert the entries to ints
            rowInt = [ int(x) for x in row ] #convert the entries into integers - so we can do calculations
            dfWhole.loc[i] = rowInt
            i = i + 1

# %%
#Method 1 - omit the tuples with missing values
#creating a pandas dataframe from csv
dfOmit = pd.DataFrame(columns=['Channel','Region', 'Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_paper', 'Delicassen'])
i = 0 #current index to insert a new row into df
with open('WholesaleCustomersDataMissing.csv', 'rt') as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        if (("" not in row) & ('Channel' not in row)): #if the row doesn't contain an empty value and is not the first row
            #convert the entries to ints
            rowInt = [ int(x) for x in row ] #convert the entries into integers
            #we have a row that doesn't contain missing values, we can keep it in our data
            dfOmit.loc[i] = rowInt
            i = i + 1

# %%
#Method 2 - fill in missing values with most probable value
dfWhole.mode()
# Out:
#     Channel  Region    Fresh    Milk  Grocery  Frozen  Detergents_paper  \
# 0       1.0     3.0      3.0   577.0    683.0   133.0                 3
# 1       NaN     NaN    514.0   659.0   1493.0   364.0                20
# 2       NaN     NaN   3366.0   829.0   1563.0   402.0                56
# 3       NaN     NaN   7149.0   899.0   1664.0   425.0                69
# 4       NaN     NaN   8040.0   944.0   2062.0   744.0                70
# 5       NaN     NaN   9670.0  1012.0   2405.0   779.0                93
# 6       NaN     NaN  18044.0  1032.0   2406.0   824.0                96
# 7       NaN     NaN      NaN  1115.0   3600.0   830.0               118
# 8       NaN     NaN      NaN  1196.0   6536.0   848.0               153
# 9       NaN     NaN      NaN  1610.0  10391.0   937.0               182
# 10      NaN     NaN      NaN  1897.0      NaN  1285.0               210
# 11      NaN     NaN      NaN  2428.0      NaN  1619.0               212
# 12      NaN     NaN      NaN  2884.0      NaN  2540.0               227
# 13      NaN     NaN      NaN  3045.0      NaN  4324.0               232
# 14      NaN     NaN      NaN  3199.0      NaN     NaN               256
# 15      NaN     NaN      NaN  3587.0      NaN     NaN               284
# 16      NaN     NaN      NaN  3880.0      NaN     NaN               311
# 17      NaN     NaN      NaN  4230.0      NaN     NaN               397
# 18      NaN     NaN      NaN  5139.0      NaN     NaN               483
# 19      NaN     NaN      NaN     NaN      NaN     NaN               788
# 20      NaN     NaN      NaN     NaN      NaN     NaN               811
# 21      NaN     NaN      NaN     NaN      NaN     NaN               918
# 22      NaN     NaN      NaN     NaN      NaN     NaN               955
#
#     Delicassen
# 0          3.0
# 1        834.0
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN

# %%
dfWhole.median()
# Out:
# Channel                1.0
# Region                 3.0
# Fresh               8504.0
# Milk                3627.0
# Grocery             4755.5
# Frozen              1526.0
# Detergents_paper     816.5
# Delicassen           965.5
# dtype: float64

# %% [markdown]
# I interpreted finding the most probable value for each category as finding the mode for each category. Unfortunately, some of the categories have multiple modes that vary greatly. For example, the category 'Fresh' has 7 mode values that range from 3 to 18044.
# Instead, we can replace the missing values with the median value from each category. The median is not as susceptible to outliers as the mean is.

# %%
#Method 2 - reaplce missing values with the median value
#creating a pandas dataframe from csv
dfReplace = pd.DataFrame(columns=['Channel','Region', 'Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_paper', 'Delicassen'])
i = 0 #current index to insert a new row into df
#dictionary of median replacement values
medians = {0: 1.0, 1: 3.0, 2:8504.0, 3:3627.0, 4:4755.5, 5:1526, 6:816.5, 7:965.5}
with open('WholesaleCustomersDataMissing.csv', 'rt') as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        if ('Channel' not in row): #if the row doesn't contain an empty value and is not the first row
            if("" in row):
                #row contains missing value, need to replace
                for j in range(0,len(row)):
                    if(row[j] == ""):
                        #we found the empty value
                        row[j] = medians[j]
            rowInt = [ int(x) for x in row ] #convert the entries into integers
        
            dfReplace.loc[i] = rowInt
            i = i + 1

# %% [markdown]
# # Conclusions
#
# Let's compare the descriptive statistics from the three data sets:

# %%
dfWhole.describe()
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_paper    Delicassen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# min       25.000000          3.000000      3.000000
# 25%      742.250000        256.750000    408.250000
# 50%     1526.000000        816.500000    965.500000
# 75%     3554.250000       3922.000000   1820.250000
# max    60869.000000      40827.000000  47943.000000

# %%
dfOmit.describe()
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  434.000000  434.000000     434.000000    434.000000    434.000000
# mean     1.324885    2.541475   11965.827189   5826.762673   8000.421659
# std      0.468872    0.774527   12636.061205   7423.721452   9553.341671
# min      1.000000    1.000000       3.000000     55.000000    137.000000
# 25%      1.000000    2.000000    3141.250000   1531.000000   2155.500000
# 50%      1.000000    3.000000    8413.500000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16905.500000   7234.500000  10699.250000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_paper    Delicassen
# count    434.000000        434.000000    434.000000
# mean    3096.175115       2906.887097   1526.020737
# std     4880.906396       4794.665933   2838.043624
# min       25.000000          3.000000      3.000000
# 25%      768.750000        256.250000    405.250000
# 50%     1567.000000        820.500000    962.500000
# 75%     3564.750000       3992.500000   1811.250000
# max    60869.000000      40827.000000  47943.000000

# %%
dfReplace.describe()
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5790.790909   7958.029545
# std      0.468052    0.774272   12647.328865   7381.092429   9497.796141
# min      1.000000    1.000000       3.000000     55.000000    137.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2156.500000
# 50%      1.000000    3.000000    8504.000000   3623.500000   4755.000000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_paper    Delicassen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2882.284091   1524.443182
# std     4854.673333       4767.489726   2820.176649
# min       25.000000          3.000000      3.000000
# 25%      742.250000        256.750000    408.250000
# 50%     1526.000000        818.000000    964.500000
# 75%     3554.250000       3922.000000   1820.250000
# max    60869.000000      40827.000000  47943.000000

# %% [markdown]
# ## Complete Data Set Compared to Data Set with Removed Tuples
# Most notably, the minimum value for Grocery went from 3 to 137 when going from the complete data set to the data with omitted tuples. There are small differences between the mean and std values, but it is difficult to tell whether the differences are significant or not.
#
# ## Complete Data Set Compared to Data Set with Replaced Values
# The mean values compared between the two data sets are almost the same. The data set with replaced values produces mean values that are much closer to the original mean values when compared with the data set with removed tuples. The same can be said about the std values between the data sets. However, the minimum value for Grocery still goes from 3 to 137 when going from the complete data set to the data with replaced values.
#
# ## Visualization Comparisons

# %%
##ggplot histogram, complete data, grocery
ggplot(aes(x = 'Grocery'), data=dfWhole) + geom_histogram()
# Out:
# <ggplot: (303758421)>

# %%
##ggplot histogram, omitted data, grocery
ggplot(aes(x = 'Grocery'), data=dfOmit) + geom_histogram()
# Out:
# <ggplot: (-9223372036550720403)>

# %%
##ggplot histogram, replaced data, grocery
ggplot(aes(x = 'Grocery'), data=dfReplace) + geom_histogram()
# Out:
# <ggplot: (-9223372036550482765)>

# %% [markdown]
# The histograms for grocery look the same for all data sets.

# %%
#scatter plot with ggplot
ggplot(dfWhole, aes(x='Milk', y='Grocery', color = 'Detergents_paper')) + geom_point()
# Out:
# <ggplot: (300956052)>

# %%
#scatter plot using data with omitted tuples
ggplot(dfOmit, aes(x='Milk', y='Grocery', color = 'Detergents_paper')) + geom_point()
# Out:
# <ggplot: (302899250)>

# %%
#scatter plot using data with replaced tuples
ggplot(dfReplace, aes(x='Milk', y='Grocery', color = 'Detergents_paper')) + geom_point()
# Out:
# <ggplot: (-9223372036551227711)>

# %% [markdown]
# ## Grocery by Milk, color grouped by Detergents_Paper - Scatterplots
# These scatter plots all exhibit the same patterns and trends. One thing to note is that as the Milk and Grocery values increase, the Detergents_paper values also seem to increase.

# %%
#scatter plot with ggplot
ggplot(dfWhole, aes(x='Fresh', y='Delicassen', color = 'Channel')) + geom_point()
# Out:
# <ggplot: (302609328)>

# %%
#scatter plot2 using data with omitted tuples
ggplot(dfOmit, aes(x='Fresh', y='Delicassen', color = 'Channel')) + geom_point()
# Out:
# <ggplot: (302503386)>

# %%
#scatter plot2 using data with replaced tuples
ggplot(dfReplace, aes(x='Fresh', y='Delicassen', color = 'Channel')) + geom_point()
# Out:
# <ggplot: (303548150)>

# %% [markdown]
# ## Fresh by Delicassen, colored by Channel - Scatterplots
# These scatterplots also seem to exhibit the same behavior for all three data sets.

# %% [markdown]
# # Highlight the Missing Data in a Plot
# Since it is difficult to see exactly what data is missing from the scatterplots and histograms, let's create a plot that specifically highlights the missing data points.
